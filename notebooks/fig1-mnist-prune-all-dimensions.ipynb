# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import os
from tqdm import tqdm
from scipy import stats
import networkx as nx
# import seaborn as sns
import re
import sys
sys.path.append("../scripts/")
from nn_sparsify_subset_fix_acc import *

plt.style.use("../config/custom_plt.mplstyle")

plt.rc('text', usetex=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%time 

dataset = 'MNIST'
hidden_size = [64]

num_samples_per_class = 100000 #1000

# Easy task
class1 = 0
class2 = 7

all_original_acc_easy_64 = []
all_results_easy_64 = []

activation_fn = 'relu'

new_range = list(range(10))

for i in new_range: 
    path = f'/home/rjankow/data/task_complexity.NOBACKUP/fix_accuracy/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    #path = f'/home/rjankow/data/task_complexity/fix_accuracy.NOBACKUP/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    original_acc_easy, results_easy = sparsify_mlp(9, path, [class1, class2], num_samples_per_class,
                                         hidden_size, verbose=False, activation_fn=activation_fn)
    all_original_acc_easy_64.append(original_acc_easy)
    all_results_easy_64.append(results_easy)
# Out:
# ...
# 100%|██████████| 38/38 [00:38<00:00,  1.02s/it]
# CPU times: user 4h 36min 30s, sys: 28.9 s, total: 4h 36min 59s
# Wall time: 6min 40s

# %%
# %%time

# Hard task
class1 = 7
class2 = 9

all_original_acc_hard_64 = []
all_results_hard_64 = []

for i in new_range:
    path = f'/home/rjankow/data/task_complexity.NOBACKUP/fix_accuracy/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
#     path = f'/home/rjankow/data/task_complexity/fix_accuracy.NOBACKUP/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    original_acc_hard, results_hard = sparsify_mlp(9, path, [class1, class2], num_samples_per_class,
                                                   hidden_size, verbose=False, activation_fn=activation_fn)
    
    all_original_acc_hard_64.append(original_acc_hard)
    all_results_hard_64.append(results_hard)
# Out:
# ...
# 100%|██████████| 38/38 [00:39<00:00,  1.04s/it]
# CPU times: user 4h 40min 54s, sys: 32.4 s, total: 4h 41min 26s
# Wall time: 6min 45s

# %%
dataset = 'MNIST'
hidden_size = [32]

num_samples_per_class = 100000 #1000

# Easy task
class1 = 0
class2 = 7

all_original_acc_easy_32 = []
all_results_easy_32 = []

activation_fn = 'relu'

new_range = list(range(10))

for i in new_range: 
    path = f'/home/rjankow/data/task_complexity.NOBACKUP/fix_accuracy/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    #path = f'/home/rjankow/data/task_complexity/fix_accuracy.NOBACKUP/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    original_acc_easy, results_easy = sparsify_mlp(9, path, [class1, class2], num_samples_per_class,
                                         hidden_size, verbose=False, activation_fn=activation_fn)
    all_original_acc_easy_32.append(original_acc_easy)
    all_results_easy_32.append(results_easy)
# Out:
# ...
# 100%|██████████| 38/38 [00:36<00:00,  1.04it/s]

# %%
# %%time

# Hard task
class1 = 7
class2 = 9

all_original_acc_hard_32 = []
all_results_hard_32 = []

for i in new_range:
    path = f'/home/rjankow/data/task_complexity.NOBACKUP/fix_accuracy/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
#     path = f'/home/rjankow/data/task_complexity/fix_accuracy.NOBACKUP/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    original_acc_hard, results_hard = sparsify_mlp(9, path, [class1, class2], num_samples_per_class,
                                                   hidden_size, verbose=False, activation_fn=activation_fn)
    
    all_original_acc_hard_32.append(original_acc_hard)
    all_results_hard_32.append(results_hard)
# Out:
# ...
# 100%|██████████| 38/38 [00:36<00:00,  1.03it/s]
# CPU times: user 4h 23min 12s, sys: 29.6 s, total: 4h 23min 42s
# Wall time: 6min 21s

# %%
dataset = 'MNIST'
hidden_size = [128]

num_samples_per_class = 100000 #1000

# Easy task
class1 = 0
class2 = 7

all_original_acc_easy_128 = []
all_results_easy_128 = []

activation_fn = 'relu'

new_range = list(range(10))

for i in new_range: 
    path = f'/home/rjankow/data/task_complexity.NOBACKUP/fix_accuracy/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    #path = f'/home/rjankow/data/task_complexity/fix_accuracy.NOBACKUP/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    original_acc_easy, results_easy = sparsify_mlp(9, path, [class1, class2], num_samples_per_class,
                                         hidden_size, verbose=False, activation_fn=activation_fn)
    all_original_acc_easy_128.append(original_acc_easy)
    all_results_easy_128.append(results_easy)
# Out:
# ...
# 100%|██████████| 38/38 [00:42<00:00,  1.13s/it]

# %%
# %%time

# Hard task
class1 = 7
class2 = 9

all_original_acc_hard_128 = []
all_results_hard_128 = []

for i in new_range:
    path = f'/home/rjankow/data/task_complexity.NOBACKUP/fix_accuracy/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
#     path = f'/home/rjankow/data/task_complexity/fix_accuracy.NOBACKUP/for_paper/output_mnist_classes_{class1}_{class2}_dim_{hidden_size[0]}_n_{num_samples_per_class}_i{i}_{activation_fn}/'
    original_acc_hard, results_hard = sparsify_mlp(9, path, [class1, class2], num_samples_per_class,
                                                   hidden_size, verbose=False, activation_fn=activation_fn)
    
    all_original_acc_hard_128.append(original_acc_hard)
    all_results_hard_128.append(results_hard)
# Out:
# ...
# 100%|██████████| 38/38 [00:43<00:00,  1.13s/it]
# CPU times: user 5h 10min 14s, sys: 31.3 s, total: 5h 10min 45s
# Wall time: 7min 28s

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_shaded_area(x, data, plot_style='median_iqr', label='', color='blue', alpha=0.2, linestyle='-', ax=None):
    """
    Plots a shaded area with a central line based on the provided data.
    
    Parameters:
      x (array-like): x-axis values.
      data (np.ndarray): 2D array where each row corresponds to a run.
      plot_style (str): 'mean_std' for mean ± standard deviation,
                        'median_iqr' for median with interquartile range.
      label (str): Label for the central line.
      color (str): Color for the shaded area and line.
      alpha (float): Transparency for the shaded area.
    """
    if plot_style == 'mean_std':
        central = np.mean(data, axis=0)
        lower = central - np.std(data, axis=0)
        upper = central + np.std(data, axis=0)
    elif plot_style == 'median_iqr':
        central = np.median(data, axis=0)
        lower = np.percentile(data, 25, axis=0)
        upper = np.percentile(data, 75, axis=0)
    else:
        raise ValueError("Unsupported plot_style. Use 'mean_std' or 'median_iqr'.")
    
    if ax is not None:
        ax.fill_between(x, lower, upper, alpha=alpha, color=color)
        ax.plot(x, central, color=color, label=label, linestyle=linestyle)
    else:
        plt.fill_between(x, lower, upper, alpha=alpha, color=color)
        plt.plot(x, central, color=color, label=label, linestyle=linestyle)

def extract_values(results, index):
    """
    Extracts values from a list of dictionaries.
    
    Parameters:
      results (list): List of dictionaries with values as iterables.
      index (int): The index to extract from each value tuple.
      
    Returns:
      np.ndarray: 2D array with extracted values.
    """
    vals = []
    for r in results:
        vals.append([x[index] for x in r.values()])
    return np.array(vals)

# %%
new_colors = [
  "#a00e00",
#   "#d04e00",
  "#f6c200",
#   "#0086a8",
  "#132b69"
]

# %%
all_fraction_non_zero = np.array(list(all_results_easy_64[0].keys()))
x = 1 - all_fraction_non_zero  # x-axis: fraction of removed edges


plt.figure(figsize=(12, 5.5))
plt.subplot(1, 2, 1)

vals_original_easy = extract_values([all_results_easy_32[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_32) > 70)], 0)
plot_shaded_area(x, vals_original_easy, plot_style='median_iqr', label='d=32', color=new_colors[0])

vals_signed_easy = extract_values([all_results_easy_32[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_32) > 70)], 1)
plot_shaded_area(x, vals_signed_easy, plot_style='median_iqr', label='', 
                 color=new_colors[0], linestyle='--')

vals_original_easy = extract_values([all_results_easy_64[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_64) > 70)], 0)
plot_shaded_area(x, vals_original_easy, plot_style='median_iqr', label='d=64', color=new_colors[1])

vals_signed_easy = extract_values([all_results_easy_64[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_64) > 70)], 1)
plot_shaded_area(x, vals_signed_easy, plot_style='median_iqr', label='', 
                 color=new_colors[1], linestyle='--')

vals_original_easy = extract_values([all_results_easy_128[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_128) > 70)], 0)
plot_shaded_area(x, vals_original_easy, plot_style='median_iqr', label='d=128', color=new_colors[2])

vals_signed_easy = extract_values([all_results_easy_128[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_128) > 70)], 1)
plot_shaded_area(x, vals_signed_easy, plot_style='median_iqr', label='', 
                 color=new_colors[2], linestyle='--')

plt.xlabel('$p$, fraction of removed edges')
plt.ylim(48, 102)
plt.title('Easy')
plt.ylabel('Accuracy')
plt.legend(loc=(0.01, 0.05))

plt.subplot(1, 2, 2)

vals_original_hard = extract_values([all_results_hard_32[int(idx)] for idx in np.argwhere(np.array(all_original_acc_hard_32) > 60)], 0)
plot_shaded_area(x, vals_original_hard, plot_style='median_iqr', label='d=32', 
                 color=new_colors[0])

vals_signed_hard = extract_values([all_results_hard_32[int(idx)] for idx in np.argwhere(np.array(all_original_acc_hard_32) > 60)], 1)
plot_shaded_area(x, vals_signed_hard, plot_style='median_iqr', label='', 
                 color=new_colors[0], linestyle='--')


vals_original_hard = extract_values([all_results_hard_64[int(idx)] for idx in np.argwhere(np.array(all_original_acc_hard_64) > 60)], 0)
plot_shaded_area(x, vals_original_hard, plot_style='median_iqr', label='d=64', 
                 color=new_colors[1])

vals_signed_hard = extract_values([all_results_hard_64[int(idx)] for idx in np.argwhere(np.array(all_original_acc_hard_64) > 60)], 1)
plot_shaded_area(x, vals_signed_hard, plot_style='median_iqr', label='', 
                 color=new_colors[1], linestyle='--')


vals_original_hard = extract_values([all_results_hard_128[int(idx)] for idx in np.argwhere(np.array(all_original_acc_hard_128) > 60)], 0)
plot_shaded_area(x, vals_original_hard, plot_style='median_iqr', label='d=128', 
                 color=new_colors[2])

vals_signed_hard = extract_values([all_results_hard_128[int(idx)] for idx in np.argwhere(np.array(all_original_acc_hard_128) > 60)], 1)
plot_shaded_area(x, vals_signed_hard, plot_style='median_iqr', label='', 
                 color=new_colors[2], linestyle='--')

plt.xlabel('$p$, fraction of removed edges')
plt.ylim(48, 102)
plt.title('Hard')

plt.suptitle('MNIST', y=0.99, fontsize=28)
plt.tight_layout()
# Out:
# /tmp/ipykernel_1018695/793248269.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   vals_original_easy = extract_values([all_results_easy_32[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_32) > 70)], 0)
# /tmp/ipykernel_1018695/793248269.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   vals_signed_easy = extract_values([all_results_easy_32[int(idx)] for idx in np.argwhere(np.array(all_original_acc_easy_32) > 70)], 1)
# ...

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import os
from tqdm import tqdm
from scipy import stats
import networkx as nx
import re
import sys
sys.path.append("../scripts/")
from data_utils import *

plt.style.use("../config/custom_plt.mplstyle")
plt.rc('text', usetex=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from train_new_subset_fix_acc_fashion_mnist import *

for i in tqdm(range(11, 20)):
    main(iteration=i)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.85% at epoch 8, step 10
#
# Training model on the easy task (Pullover vs Sneaker)...
#  11%|█         | 1/9 [1:04:11<8:33:28, 3851.05s/it]
# Easy Task Results:
# Final Test Accuracy: 97.40% at epoch 9, step 27
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.15% at epoch 9, step 9
#
# Training model on the easy task (Pullover vs Sneaker)...
#  22%|██▏       | 2/9 [2:05:37<7:17:58, 3754.02s/it]
# Easy Task Results:
# Final Test Accuracy: 97.30% at epoch 9, step 47
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.70% at epoch 4, step 23
#
# Training model on the easy task (Pullover vs Sneaker)...
#  33%|███▎      | 3/9 [3:07:21<6:13:07, 3731.33s/it]
# Easy Task Results:
# Final Test Accuracy: 97.45% at epoch 9, step 15
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.75% at epoch 7, step 33
#
# Training model on the easy task (Pullover vs Sneaker)...
#  44%|████▍     | 4/9 [4:08:58<5:09:49, 3717.90s/it]
# Easy Task Results:
# Final Test Accuracy: 97.40% at epoch 8, step 73
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.95% at epoch 8, step 52
#
# Training model on the easy task (Pullover vs Sneaker)...
#  56%|█████▌    | 5/9 [5:10:49<4:07:40, 3715.22s/it]
# Easy Task Results:
# Final Test Accuracy: 97.15% at epoch 5, step 26
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.80% at epoch 8, step 61
#
# Training model on the easy task (Pullover vs Sneaker)...
#  67%|██████▋   | 6/9 [6:13:26<3:06:28, 3729.46s/it]
# Easy Task Results:
# Final Test Accuracy: 97.45% at epoch 8, step 59
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.65% at epoch 5, step 80
#
# Training model on the easy task (Pullover vs Sneaker)...
#  78%|███████▊  | 7/9 [7:14:52<2:03:50, 3715.31s/it]
# Easy Task Results:
# Final Test Accuracy: 97.40% at epoch 9, step 1
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.95% at epoch 8, step 10
#
# Training model on the easy task (Pullover vs Sneaker)...
#  89%|████████▉ | 8/9 [8:16:21<1:01:46, 3706.95s/it]
# Easy Task Results:
# Final Test Accuracy: 97.45% at epoch 9, step 56
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.90% at epoch 5, step 86
#
# Training model on the easy task (Pullover vs Sneaker)...
# 100%|██████████| 9/9 [9:19:11<00:00, 3727.90s/it]
# Easy Task Results:
# Final Test Accuracy: 97.25% at epoch 3, step 2

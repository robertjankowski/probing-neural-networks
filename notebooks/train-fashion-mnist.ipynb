# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import os
from tqdm import tqdm
from scipy import stats
import networkx as nx
import re
import sys
sys.path.append("../scripts/")
from data_utils import *

plt.style.use("../config/custom_plt.mplstyle")
plt.rc('text', usetex=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from train_new_subset_fix_acc_fashion_mnist import *

# for i in tqdm(range(20)):
#     main(iteration=i)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.25% at epoch 9, step 82
#
# Training model on the easy task (Pullover vs Sneaker)...
#   5%|▌         | 1/20 [07:21<2:19:55, 441.84s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 7, step 35
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.30% at epoch 9, step 60
#
# Training model on the easy task (Pullover vs Sneaker)...
#  10%|█         | 2/20 [16:00<2:26:06, 487.03s/it]
# Easy Task Results:
# Final Test Accuracy: 97.40% at epoch 8, step 41
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.85% at epoch 7, step 80
#
# Training model on the easy task (Pullover vs Sneaker)...
#  15%|█▌        | 3/20 [25:22<2:27:40, 521.21s/it]
# Easy Task Results:
# Final Test Accuracy: 97.75% at epoch 9, step 22
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.25% at epoch 7, step 2
#
# Training model on the easy task (Pullover vs Sneaker)...
#  20%|██        | 4/20 [33:57<2:18:18, 518.64s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 9, step 4
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.25% at epoch 7, step 57
#
# Training model on the easy task (Pullover vs Sneaker)...
#  25%|██▌       | 5/20 [43:04<2:12:15, 529.01s/it]
# Easy Task Results:
# Final Test Accuracy: 97.65% at epoch 9, step 48
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.70% at epoch 4, step 7
#
# Training model on the easy task (Pullover vs Sneaker)...
#  30%|███       | 6/20 [51:51<2:03:15, 528.27s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 8, step 90
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.35% at epoch 9, step 52
#
# Training model on the easy task (Pullover vs Sneaker)...
#  35%|███▌      | 7/20 [1:00:48<1:55:07, 531.31s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 9, step 68
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.25% at epoch 7, step 65
#
# Training model on the easy task (Pullover vs Sneaker)...
#  40%|████      | 8/20 [1:09:36<1:46:02, 530.22s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 10, step 38
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.35% at epoch 7, step 91
#
# Training model on the easy task (Pullover vs Sneaker)...
#  45%|████▌     | 9/20 [1:17:52<1:35:12, 519.31s/it]
# Easy Task Results:
# Final Test Accuracy: 97.45% at epoch 8, step 19
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.00% at epoch 9, step 79
#
# Training model on the easy task (Pullover vs Sneaker)...
#  50%|█████     | 10/20 [1:25:57<1:24:49, 508.96s/it]
# Easy Task Results:
# Final Test Accuracy: 97.45% at epoch 8, step 82
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.80% at epoch 9, step 48
#
# Training model on the easy task (Pullover vs Sneaker)...
#  55%|█████▌    | 11/20 [1:34:42<1:17:03, 513.78s/it]
# Easy Task Results:
# Final Test Accuracy: 97.60% at epoch 10, step 1
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.10% at epoch 8, step 65
#
# Training model on the easy task (Pullover vs Sneaker)...
#  60%|██████    | 12/20 [1:43:03<1:07:58, 509.82s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 9, step 37
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.05% at epoch 8, step 80
#
# Training model on the easy task (Pullover vs Sneaker)...
#  65%|██████▌   | 13/20 [1:52:35<1:01:41, 528.76s/it]
# Easy Task Results:
# Final Test Accuracy: 97.70% at epoch 10, step 25
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.10% at epoch 8, step 84
#
# Training model on the easy task (Pullover vs Sneaker)...
#  70%|███████   | 14/20 [2:02:04<54:04, 540.78s/it]
# Easy Task Results:
# Final Test Accuracy: 97.45% at epoch 8, step 60
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.65% at epoch 4, step 75
#
# Training model on the easy task (Pullover vs Sneaker)...
#  75%|███████▌  | 15/20 [2:10:54<44:48, 537.67s/it]
# Easy Task Results:
# Final Test Accuracy: 97.50% at epoch 6, step 73
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.05% at epoch 7, step 91
#
# Training model on the easy task (Pullover vs Sneaker)...
#  80%|████████  | 16/20 [2:21:10<37:24, 561.15s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 6, step 55
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.40% at epoch 6, step 45
#
# Training model on the easy task (Pullover vs Sneaker)...
#  85%|████████▌ | 17/20 [2:29:18<26:57, 539.22s/it]
# Easy Task Results:
# Final Test Accuracy: 97.50% at epoch 10, step 90
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.00% at epoch 5, step 70
#
# Training model on the easy task (Pullover vs Sneaker)...
#  90%|█████████ | 18/20 [2:37:39<17:35, 527.67s/it]
# Easy Task Results:
# Final Test Accuracy: 97.55% at epoch 8, step 21
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 97.60% at epoch 5, step 25
#
# Training model on the easy task (Pullover vs Sneaker)...
#  95%|█████████▌| 19/20 [2:46:10<08:42, 522.82s/it]
# Easy Task Results:
# Final Test Accuracy: 97.50% at epoch 8, step 6
# Training model on the hard task (Sandal vs Sneaker)...
#
# Hard Task Results:
# Max Test Accuracy: 98.30% at epoch 8, step 54
#
# Training model on the easy task (Pullover vs Sneaker)...
# 100%|██████████| 20/20 [2:55:32<00:00, 526.65s/it]
# Easy Task Results:
# Final Test Accuracy: 97.40% at epoch 8, step 12
